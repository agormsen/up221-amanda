# %% [markdown]
# # Week 2 Assignment: Data Exploration of Cooling and Warming Centers in LA County
# This dataset (csv file) contains the locations of cooling and warming centers in Los Angeles County. I want to explore where the cooling and warming centers are located and what their operating hours are to determine if there are apparent gaps in service and operations of these centers. This may help inform future identification and implementation of cooling and warming centers across LA County to make them more accessible and equitable.
# URL Source: https://geohub.lacity.org/datasets/lacounty::cooling-and-warming-centers/about

# %% [markdown]
# import pandas and geopandas

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# read and add zip file to notebook

# %%
centers = gpd.read_file('Cooling_and_Warming_Centers.zip')

# %% [markdown]
# what's the data type?

# %%
type(centers)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# what does the data look like? printed the first 5 rows of data so see all the columns in the dataset

# %%
centers.head()
# Out:
#    OBJECTID source ext_id                cat1            cat2  cat3  \
# 0       900    211   None  Emergency Response  Cooling Center  None
# 1       944    211   None  Emergency Response  Cooling Center  None
# 2      1913    211   None  Emergency Response  Cooling Center  None
# 3      1946    211   None  Emergency Response  Cooling Center  None
# 4      1949    211   None  Emergency Response  Cooling Center  None
#
#                    org_name  \
# 0  www.asianyouthcenter.org
# 1    www.ci.claremont.ca.us
# 2     www.onegeneration.org
# 3          css.lacounty.gov
# 4    www.cityofsandimas.com
#
#                                                 Name                addrln1  \
# 0                                 Asian Youth Center      100 W. Clary Ave.
# 1  City Of Claremont Senior Services - Joslyn Sen...   660 N. Mountain Ave.
# 2           Onegeneration - Senior Enrichment Center    18255 Victory Blvd.
# ...

# %% [markdown]
# learning more about the data, how many rows and columns does it have?

# %%
centers.shape
# Out:
# (92, 30)

# %% [markdown]
# There are 92 rows and 30 columns. Next, I will look at a random sample of 5 rows

# %%
centers.sample(5)
# Out:
#     OBJECTID                                             source ext_id  \
# 4       1949                                                211   None
# 67     64883                                                211   None
# 89     71407  LA County Department of Community and Senior S...   None
# 76     71379  LA County Department of Community and Senior S...   None
# 80     71387  LA County Department of Community and Senior S...   None
#
#                   cat1            cat2  cat3  \
# 4   Emergency Response  Cooling Center  None
# 67  Emergency Response  Cooling Center  None
# 89  Emergency Response  Cooling Center  None
# 76  Emergency Response  Cooling Center  None
# 80  Emergency Response  Cooling Center  None
#
#                                              org_name  \
# 4                              www.cityofsandimas.com
# 67                                               None
# 89                               City of San Fernando
# ...

# %% [markdown]
# Now, I will learn even more about the data

# %%
centers.info
# Out:
# <bound method DataFrame.info of     OBJECTID                                             source ext_id  \
# 0        900                                                211   None
# 1        944                                                211   None
# 2       1913                                                211   None
# 3       1946                                                211   None
# 4       1949                                                211   None
# ..       ...                                                ...    ...
# 87     71403  LA County Department of Community and Senior S...   None
# 88     71405  LA County Department of Community and Senior S...   None
# 89     71407  LA County Department of Community and Senior S...   None
# 90     71410  LA County Department of Community and Senior S...   None
# 91     71412  LA County Department of Community and Senior S...   None
#
#                   cat1            cat2  cat3  \
# ...

# %% [markdown]
# Now, I will look at the first three rows of data

# %%
centers.head(3)
# Out:
#    OBJECTID source ext_id                cat1            cat2  cat3  \
# 0       900    211   None  Emergency Response  Cooling Center  None
# 1       944    211   None  Emergency Response  Cooling Center  None
# 2      1913    211   None  Emergency Response  Cooling Center  None
#
#                    org_name  \
# 0  www.asianyouthcenter.org
# 1    www.ci.claremont.ca.us
# 2     www.onegeneration.org
#
#                                                 Name               addrln1  \
# 0                                 Asian Youth Center     100 W. Clary Ave.
# 1  City Of Claremont Senior Services - Joslyn Sen...  660 N. Mountain Ave.
# 2           Onegeneration - Senior Enrichment Center   18255 Victory Blvd.
#
#   addrln2  ...                                   link use_type   latitude  \
# 0    None  ...  http://egis3.lacounty.gov/lms/?p=1061  publish  34.097646
# 1    None  ...  http://egis3.lacounty.gov/lms/?p=1072  publish  34.099674
# ...

# %% [markdown]
# Next, I will identify the columns and attempt to run a value counts

# %%
centers.columns.to_list()
# Out:
# ['OBJECTID',
#  'source',
#  'ext_id',
#  'cat1',
#  'cat2',
#  'cat3',
#  'org_name',
#  'Name',
#  'addrln1',
#  'addrln2',
#  'city',
#  'state',
#  'hours',
#  'phones',
#  'url',
#  'info1',
#  'info2',
#  'post_id',
#  'descriptio',
#  'zip',
#  'link',
#  'use_type',
#  'latitude',
#  'longitude',
#  'email',
#  'date_updat',
#  'dis_status',
#  'POINT_X',
#  'POINT_Y',
#  'geometry']

# %%
centers['city'].sample(5)
# Out:
# 50            Carson
# 23            Downey
# 72         Irwindale
# 0        San Gabriel
# 59    Marina Del Rey
# Name: city, dtype: object

# %%
centers['city'].value_counts()
# Out:
# Los Angeles         9
# Claremont           4
# Whittier            4
# Azusa               3
# Santa Clarita       3
# Pomona              3
# Norwalk             3
# Glendale            2
# Lakewood            2
# Burbank             2
# Compton             2
# Altadena            2
# Baldwin Park        2
# Downey              2
# El Monte            2
# Torrance            2
# Monrovia            2
# South Pasadena      2
# Arcadia             2
# Gardena             2
# La Puente           1
# Montebello          1
# Hawaiian Gardens    1
# Marina Del Rey      1
# Manhattan Beach     1
# San Fernando        1
# Paramount           1
# Rowland Heights     1
# Alhambra            1
# Westlake Village    1
# Littlerock          1
# Newhall             1
# La Mirada           1
# Palmdale            1
# Duarte              1
# Irwindale           1
# San Gabriel         1
# Covina              1
# Diamond Bar         1
# Monterey Park       1
# Reseda              1
# ...

# %% [markdown]
# Plotting number of cooling/warming centers by city

# %%
city_count=centers['city'].value_counts()

# %%
city_count.plot.bar()
# Out:
# <AxesSubplot: >

# %% [markdown]
# I would like to learn to make the city name more readable but I am satisfied with this output

# %% [markdown]
# Now I will attempt a filter/query for Los Angeles cooling centers as that is the city with the highest number of centers

# %%
centers.query("city == 'Los Angeles'")
# Out:
#     OBJECTID                                             source ext_id  \
# 5       2558                                                211   None
# 8      55299                                                211   None
# 17     56826                                                211   None
# 43     62539                                                211   None
# 55     63040                                                211   None
# 81     71389                                               None   None
# 82     71391  LA County Department of Community and Senior S...   None
# 83     71393  LA County Department of Community and Senior S...   None
# 84     71395  LA County Department of Community and Senior S...   None
#
#                   cat1            cat2  cat3  \
# 5   Emergency Response  Cooling Center  None
# 8   Emergency Response  Cooling Center  None
# 17  Emergency Response  Cooling Center  None
# 43  Emergency Response  Cooling Center  None
# ...
