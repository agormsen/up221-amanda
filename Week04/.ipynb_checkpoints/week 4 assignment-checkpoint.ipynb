# %% [markdown]
# # Week 4 Assignment: Census Data Exploration
# # Group Name: Extreme Heat in Los Angeles
# This week, I will attempt to expand on last week's assignment. I hope to try to overlap a map of LA transit system with its existing cooling center locations. Long-term, I hope to add in tree canopy data.
#
# Author: Amanda Gormsen

# %%
import pandas as pd

# %% [markdown]
# Next, I will load and read the data, "Cooling Heating Centers City of Los Angeles"

# %%
df = pd.read_csv('Cooling_Heating_Centers_City_of_Los_Angeles.csv')

# %% [markdown]
# Preliminary inspection of the data. I will look at the size of the data.

# %%
df.shape
# Out:
# (31, 10)

# %% [markdown]
# This means that there are 31 rows and 10 columns in this file

# %%
df.head()
# Out:
#             X          Y  OBJECTID                              GlobalID  \
# 0 -118.602643  34.203725        64  19c09964-74b3-47b8-b213-6b2415619201
# 1 -118.448115  34.163176        65  078b0c25-92be-47d8-ab89-0cd8194693a1
# 2 -118.612515  34.176359        66  8679f582-4287-4746-b802-afaebdfabdfd
# 3 -118.379437  34.167728        67  884db8bd-e2cb-4a80-9eaa-d13e896183bb
# 4 -118.321488  34.261219        68  4136e594-5cb1-48be-9e51-28edbac3b9ad
#
#                             FacilityName IndoorOutdoor  \
# 0      Canoga Park Senior Citizen Center        Indoor
# 1  Sherman Oaks East Valley Adult Center
# 2       Woodland Hills Recreation Center
# 3          North Hollywood Senior Center
# 4                  Sunland Senior Center
#
#                                            Address  Bureau CouncilDistrict  \
# 0     7326 Jordan Ave, Canoga Park, CA, 91303, USA  Valley              03
# 1       5056 Van Nuys Blvd. Sherman Oaks, CA 91403  Valley              04
# ...

# %% [markdown]
# I want to see all the data displayed now.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.sample()
# Out:
#              X          Y  OBJECTID                              GlobalID  \
# 10 -118.371435  34.275115        75  439992ab-0d34-4a5d-8f30-e6bedf0620d7
#
#                     FacilityName IndoorOutdoor  \
# 10  Lake View Terrace Rec Center
#
#                                              Address  Bureau CouncilDistrict  \
# 10  11075 Foothill Blvd, Lake View Terrace, CA 91342  Valley              07
#
#    AltFacPhone
# 10

# %% [markdown]
# Now I will look at the data types

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   X                31 non-null     float64
#  1   Y                31 non-null     float64
#  2   OBJECTID         31 non-null     int64
#  3   GlobalID         31 non-null     object
#  4   FacilityName     30 non-null     object
#  5   IndoorOutdoor    28 non-null     object
#  6   Address          30 non-null     object
#  7   Bureau           30 non-null     object
#  8   CouncilDistrict  30 non-null     object
#  9   AltFacPhone      21 non-null     object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 2.5+ KB

# %% [markdown]
# Now, I am not sure how to go about "overlaying" different data sets but I will attempt to import more...

# %%
df2 = pd.read_csv('Bus_Stop_Benches.csv')

# %%
df2.shape
# Out:
# (5332, 15)

# %% [markdown]
# It worked! This means that there are 5332 rows and 15 columns in the "Bus Stop Benches" file. This is a lot of rows so I will run a sample now.

# %%
df2.sample(10)
# Out:
#                X          Y  OBJECTID  FID2   NUMBER  LATITUDE  LONGITUDE  \
# 4849 -118.457408  34.164655      4850   337  LA-0338  34.16466 -118.45742
# 1287 -118.462378  33.998805      1288  3545  LA-3546  33.99881 -118.46239
# 2432 -118.247698  33.994605      2433  2853  LA-2854  33.99461 -118.24771
# 2212 -118.605898  34.199925      2213  5310  LA-5311  34.19993 -118.60591
# 3490 -118.418248  34.061455      3491  1997  LA-1998  34.06146 -118.41826
# 3976 -118.363688  34.050815      3977  3182  LA-3183  34.05082 -118.36370
# 470  -118.295918  34.101685       471  4604  LA-4605  34.10169 -118.29593
# 1084 -118.566578  34.242685      1085  4290  LA-4291  34.24269 -118.56659
# 1016 -118.300708  34.101655      1017  4609  LA-4610  34.10166 -118.30072
# 1340 -118.308978  34.057485      1341  3311  LA-3312  34.05749 -118.30899
#
#                                    SITEATS         CITY_SITE FACING  \
# 4849          SB  Kester  FS  Magnolia -SW  L.A. Valley West   East
# ...

# %%
df2.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5332 entries, 0 to 5331
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           5332 non-null   float64
#  1   Y           5332 non-null   float64
#  2   OBJECTID    5332 non-null   int64
#  3   FID2        5332 non-null   int64
#  4   NUMBER      5332 non-null   object
#  5   LATITUDE    5332 non-null   float64
#  6   LONGITUDE   5332 non-null   float64
#  7   SITEATS     5332 non-null   object
#  8   CITY_SITE   5332 non-null   object
#  9   FACING      5332 non-null   object
#  10  MEDIA_TYPE  5332 non-null   object
#  11  UNIT_TYPE   5332 non-null   object
#  12  AREA        5332 non-null   object
#  13  ADVERTISER  5332 non-null   object
#  14  TOOLTIP     5332 non-null   object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 625.0+ KB

# %% [markdown]
# Now I will repeat the above import process 2 more times with the remaining LA Bus Lines & Metro Rail Lines Stops data.

# %%
df3 = pd.read_csv('Metro_Bus_Lines.csv')

# %%
df3.shape
# Out:
# (811, 11)

# %% [markdown]
# This means that there are 811 rows and 11 columns in the "Metro Bus Lines" file.

# %%
df3.sample(10)
# Out:
#      OBJECTID  VAR_ROUTE VAR_IDENT              VAR_DESCR  VAR_DIREC  \
# 525       526        190        W1       -190- END TO END          3
# 269       270         78        W1                78 WEST          3
# 255       256         76        E2   LATE NIGHT OWL TRIPS          2
# 42         43        460        S3  ROSECRANS DETOUR 2013          2
# 1           2        603        S1             END TO END          1
# 132       133         30        E1             END TO END          2
# 47         48        487        E2              ROUTE 489          2
# 202       203         53        N1             END TO END          0
# 807       808        910        N1             End to End          0
# 102       103         16        E2  S/L S-VICENTE G.ALLEN          2
#
#     MetroCategory                    MetroBusType  RouteNumber  \
# 525   LocalNonCBD         Metro Local and Limited          190
# 269      LocalCBD         Metro Local and Limited           78
# ...

# %%
df3.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID       811 non-null    int64
#  1   VAR_ROUTE      811 non-null    int64
#  2   VAR_IDENT      809 non-null    object
#  3   VAR_DESCR      811 non-null    object
#  4   VAR_DIREC      811 non-null    int64
#  5   MetroCategory  811 non-null    object
#  6   MetroBusType   811 non-null    object
#  7   RouteNumber    811 non-null    int64
#  8   RouteName      811 non-null    object
#  9   TOOLTIP        811 non-null    object
#  10  NLA_URL        811 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 69.8+ KB

# %% [markdown]
# Now, time for the last file import

# %%
df4 = pd.read_csv('Metro_Rail_Lines_Stops.csv')

# %%
df4.shape
# Out:
# (104, 8)

# %% [markdown]
# This means that there are 104 rows and 8 columns in the "Metro Rail Lines Stops" file.

# %%
df4.sample(10)
# Out:
#              X          Y  OBJECTID   MetroLine                    Station  \
# 52 -118.377134  33.929621        53  Green Line     Aviation / LAX Station
# 62 -118.154469  34.033398        63   Gold Line           Atlantic Station
# 57 -118.265217  33.927465        58  Green Line             Avalon Station
# 39 -118.291686  34.076526        40    Red Line  Vermont / Beverly Station
# 64 -118.168140  34.033319        65   Gold Line          Maravilla Station
# 32 -118.376808  34.168504        33    Red Line    North Hollywood Station
# 29 -118.388986  34.027896        30   Expo Line        Culver City Station
# 94 -117.906631  34.135863        95   Gold Line     Azusa Downtown Station
# 55 -118.291733  33.928683        56  Green Line   Vermont / Athens Station
# 1  -118.193700  33.772258         2   Blue Line        Pacific Ave Station
#
#     StopNumber                                            TOOLTIP  \
# 52       80305  Stop: Aviation / LAX Station\nStop No: 80305\n...
# ...

# %%
df4.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   X           104 non-null    float64
#  1   Y           104 non-null    float64
#  2   OBJECTID    104 non-null    int64
#  3   MetroLine   104 non-null    object
#  4   Station     104 non-null    object
#  5   StopNumber  104 non-null    int64
#  6   TOOLTIP     104 non-null    object
#  7   NLA_URL     104 non-null    object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 6.6+ KB

# %% [markdown]
# Now, I will attempt to make some maps...

# %%
import geopandas as gpd

# %%
centers=gpd.read_file('Cooling_Heating_Centers_City_of_Los_Angeles.geojson')
centers.head()
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed
#    OBJECTID                              GlobalID  \
# 0        64  19c09964-74b3-47b8-b213-6b2415619201
# 1        65  078b0c25-92be-47d8-ab89-0cd8194693a1
# 2        66  8679f582-4287-4746-b802-afaebdfabdfd
# 3        67  884db8bd-e2cb-4a80-9eaa-d13e896183bb
# 4        68  4136e594-5cb1-48be-9e51-28edbac3b9ad
#
#                             FacilityName IndoorOutdoor  \
# 0      Canoga Park Senior Citizen Center        Indoor
# 1  Sherman Oaks East Valley Adult Center
# 2       Woodland Hills Recreation Center
# 3          North Hollywood Senior Center
# 4                  Sunland Senior Center
#
#                                            Address  Bureau CouncilDistrict  \
# 0     7326 Jordan Ave, Canoga Park, CA, 91303, USA  Valley              03
# 1       5056 Van Nuys Blvd. Sherman Oaks, CA 91403  Valley              04
# 2        5858 Shoup Ave., Woodland Hills, CA 91367  Valley              03
# ...

# %%
# plot it!
centers.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# Time to repeat with the other 3 files...

# %%
benches=gpd.read_file('Bus_Stop_Benches.geojson')
benches.head()
# Out:
#    OBJECTID  FID2   NUMBER  LATITUDE  LONGITUDE  \
# 0         1   663  LA-0664  34.19462 -118.58843
# 1         2   681  LA-0682  34.20065 -118.62340
# 2         3   682  LA-0683  34.20065 -118.62340
# 3         4   711  LA-0712  34.15238 -118.60487
# 4         5   771  LA-0772  34.21597 -118.53582
#
#                               SITEATS         CITY_SITE FACING MEDIA_TYPE  \
# 0        NB  De Soto  FS  Vanowen -NE  L.A. Valley West  South  Bus Bench
# 1  SB  Fallbrook  FS  Sherman Way -SW  L.A. Valley West   East  Bus Bench
# 2  SB  Fallbrook  FS  Sherman Way -SW  L.A. Valley West   East  Bus Bench
# 3   EB  Mulholland D  NS  Topanga -SW  L.A. Valley West   East  Bus Bench
# 4   NB  Reseda Blvd FS  Strathern -NE  L.A. Valley West  South  Bus Bench
#
#          UNIT_TYPE   AREA   ADVERTISER  \
# 0  Recycle Plastic  CD-03     MOM L.A.
# 1  Recycle Plastic  CD-03  Jerry Gooze
# 2  Recycle Plastic  CD-03  Jerry Gooze
# 3  Recycle Plastic  CD-03     MOM L.A.
# ...

# %%
# plot it!
benches.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# We can already tell there are wayyyy more bus stop benches than cooling centers in LA. This is obvious due to demand for the services.

# %%
buslines=gpd.read_file('Metro_Bus_Lines.geojson')
buslines.head()
# Out:
#    OBJECTID VAR_ROUTE VAR_IDENT           VAR_DESCR  VAR_DIREC MetroCategory  \
# 0         1       603        N1          END TO END          0       ComCirc
# 1         2       603        S1          END TO END          1       ComCirc
# 2         3       605        N1          END TO END          0       ComCirc
# 3         4       605        S1          END TO END          1       ComCirc
# 4         5       607        A2  New Clockwise Loop          8       ComCirc
#
#                      MetroBusType  RouteNumber  \
# 0  Metro Shuttles and Circulators          603
# 1  Metro Shuttles and Circulators          603
# 2  Metro Shuttles and Circulators          605
# 3  Metro Shuttles and Circulators          605
# 4  Metro Shuttles and Circulators          607
#
#                                            RouteName  \
# 0  603 Glendale-Grand Sta Via San Fernando-Rampar...
# 1  603 Glendale-Grand Sta Via San Fernando-Rampar...
# ...

# %%
# plot it!
buslines.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# In comparing the bus lines to the bus benches map, I think I prefer the data visualization of the bus lines...I think it is more user-friendly to see how a rider may be connected to cooling centers in the city.

# %%
raillines=gpd.read_file('Metro_Rail_Lines_Stops.geojson')
raillines.head()
# Out:
#    OBJECTID  MetroLine                      Station  StopNumber  \
# 0         1  Blue Line  Downtown Long Beach Station       80101
# 1         2  Blue Line          Pacific Ave Station       80102
# 2         3  Blue Line       Anaheim Street Station       80105
# 3         4  Blue Line    Pacific Coast Hwy Station       80106
# 4         5  Blue Line        Willow Street Station       80107
#
#                                              TOOLTIP  \
# 0  Stop: Downtown Long Beach Station\nStop No: 80...
# 1  Stop: Pacific Ave Station\nStop No: 80102\nBlu...
# 2  Stop: Anaheim Street Station\nStop No: 80105\n...
# 3  Stop: Pacific Coast Hwy Station\nStop No: 8010...
# 4  Stop: Willow Street Station\nStop No: 80107\nB...
#
#                                              NLA_URL  \
# 0  http://www.metro.net/riding/maps/blue-line/?nl...
# 1  http://www.metro.net/riding/maps/blue-line/?nl...
# 2  http://www.metro.net/riding/maps/blue-line/?nl...
# ...

# %%
# plot it!
raillines.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# I think maybe next time I will dowload the rail lines map instead of the rail lines STOPS map. Lastly, I will attempt some sort of interactive map.

# %%
import folium

# %%
m = folium.Map(location=[34.2,-118.2], 
               zoom_start = 9,
               tiles='CartoDB positron', 
               attribution='CartoDB')

# %%
# plot chorpleth over the base map
folium.Choropleth('Metro_Rail_Lines_Stops.geojson')

# %% [markdown]
# I am not positive how to troubleshoot this but I will try next week.
